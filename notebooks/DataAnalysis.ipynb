# %% [markdown]
# ### <span style="color:orange">Importing Libraries</span>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### <span style="color:orange;">Load the Dataset</span>

# %%
df=pd.read_csv("Salary Data.csv")

# %%
df.head(6)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
# 5  29.0    Male      Bachelor's  Marketing Analyst                  2.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0
# 5   55000.0

# %%
df.tail(6)
# Out:
#       Age  Gender Education Level                      Job Title  \
# 369  33.0    Male      Bachelor's        Junior Business Analyst
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 369                  4.0   60000.0
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0

# %%
df.sample(6)
# Out:
#       Age Gender Education Level                     Job Title  \
# 195  28.0   Male      Bachelor's       Junior Business Analyst
# 68   34.0   Male        Master's  Business Development Manager
# 301  31.0   Male      Bachelor's        Junior Project Manager
# 70   33.0   Male      Bachelor's                 Web Developer
# 143  47.0   Male      Bachelor's          Senior Sales Manager
# 325  36.0   Male      Bachelor's     Senior Operations Manager
#
#      Years of Experience    Salary
# 195                  2.0   40000.0
# 68                   8.0   90000.0
# 301                  3.0   55000.0
# 70                   6.0   65000.0
# 143                 20.0  135000.0
# 325                  9.0  100000.0

# %% [markdown]
# ### <span style="color:orange;"> Dataset Overview</span>

# %%
df.shape
# Out:
# (375, 6)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %% [markdown]
# ### <span style="color:orange">Extract Unique Values</span>

# %%
df["Age"].unique()
# Out:
# array([32., 28., 45., 36., 52., 29., 42., 31., 26., 38., 48., 35., 40.,
#        27., 44., 33., 39., 25., 51., 34., 47., 30., 41., 37., 24., 43.,
#        50., 46., 49., 23., 53., nan])

# %%
df["Age"].nunique()
# Out:
# 31

# %%
df["Education Level"].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', nan], dtype=object)

# %%
df["Job Title"].nunique()
# Out:
# 174

# %%
df["Salary"].nunique()
# Out:
# 36

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      194
# Female    179
# Name: count, dtype: int64

# %%
df["Education Level"].value_counts()
# Out:
# Education Level
# Bachelor's    224
# Master's       98
# PhD            51
# Name: count, dtype: int64

# %%
pd.crosstab(df["Education Level"], df["Gender"])
# Out:
# Gender           Female  Male
# Education Level
# Bachelor's          103   121
# Master's             50    48
# PhD                  26    25

# %%
df["Job Title"].value_counts()
# Out:
# Job Title
# Director of Marketing             12
# Director of Operations            11
# Senior Business Analyst           10
# Senior Marketing Manager           9
# Senior Marketing Analyst           9
#                                   ..
# Junior Social Media Specialist     1
# Junior Operations Coordinator      1
# Senior HR Specialist               1
# Director of HR                     1
# Junior Financial Advisor           1
# Name: count, Length: 174, dtype: int64

# %% [raw]
# ### <span style="color:orange">Relationship between various columns</span>

# %%
pd.crosstab(df["Job Title"], df["Education Level"])
# Out:
# Education Level               Bachelor's  Master's  PhD
# Job Title
# Account Manager                        1         0    0
# Accountant                             1         0    0
# Administrative Assistant               2         0    0
# Business Analyst                       1         1    0
# Business Development Manager           0         1    0
# ...                                  ...       ...  ...
# UX Designer                            0         1    0
# UX Researcher                          0         1    0
# VP of Finance                          0         1    0
# VP of Operations                       0         1    0
# Web Developer                          1         0    0
#
# [174 rows x 3 columns]

# %%
pd.crosstab(df["Education Level"], df["Gender"])
# Out:
# Gender           Female  Male
# Education Level
# Bachelor's          103   121
# Master's             50    48
# PhD                  26    25

# %%
pd.crosstab(df["Education Level"],df["Salary"])
# Out:
# Salary           350.0     30000.0   35000.0   40000.0   45000.0   50000.0   \
# Education Level
# Bachelor's              1         1        13        30        16        21
# Master's                0         0         0         1         2         1
# PhD                     0         0         0         0         0         0
#
# Salary           55000.0   60000.0   65000.0   70000.0   ...  155000.0  \
# Education Level                                          ...
# Bachelor's             10        17         7         9  ...         0
# Master's                0         0         2         0  ...         0
# PhD                     0         0         0         0  ...         1
#
# Salary           160000.0  170000.0  175000.0  180000.0  185000.0  190000.0  \
# Education Level
# Bachelor's              2         0         0         1         0         0
# Master's                2        14         2        13         0         3
# ...

# %%
pd.crosstab(df["Gender"],df["Salary"])
# Out:
# Salary  350.0     30000.0   35000.0   40000.0   45000.0   50000.0   55000.0   \
# Gender
# Female         0         0         5        16        12        13         6
# Male           1         1         8        15         6         9         4
#
# Salary  60000.0   65000.0   70000.0   ...  155000.0  160000.0  170000.0  \
# Gender                                ...
# Female         5         5         6  ...         0        10         2
# Male          12         4         3  ...         1         7        14
#
# Salary  175000.0  180000.0  185000.0  190000.0  200000.0  220000.0  250000.0
# Gender
# Female         0        12         1         1         0         0         0
# Male           2         8         0         3         2         1         2
#
# [2 rows x 36 columns]

# %% [markdown]
# ### <span style="color:orange"> Experience among the employees</span>

# %%
df.groupby("Job Title")["Years of Experience"].mean().sort_values(ascending=False)
# Out:
# Job Title
# CEO                                25.0
# Chief Technology Officer           24.0
# Director of Sales and Marketing    22.0
# Director of Human Resources        22.0
# Sales Director                     22.0
#                                    ...
# Customer Success Rep                1.0
# Junior Developer                    1.0
# Data Entry Clerk                    0.0
# Help Desk Analyst                   0.0
# Sales Representative                0.0
# Name: Years of Experience, Length: 174, dtype: float64

# %%
df.groupby("Education Level")["Years of Experience"].mean()
# Out:
# Education Level
# Bachelor's     6.966518
# Master's      13.397959
# PhD           17.019608
# Name: Years of Experience, dtype: float64

# %%
df.groupby("Gender")["Years of Experience"].mean().sort_values(ascending=False)
# Out:
# Gender
# Male      10.048969
# Female    10.011173
# Name: Years of Experience, dtype: float64

# %% [markdown]
# ### <span style="color:orange">Salary Analysis</span>

# %%
df["Salary"].unique()
# Out:
# array([ 90000.,  65000., 150000.,  60000., 200000.,  55000., 120000.,
#         80000.,  45000., 110000.,  75000., 140000., 130000.,  40000.,
#        125000., 115000.,  35000., 180000., 190000.,  50000., 250000.,
#        170000., 160000.,  85000.,  95000., 105000.,  70000., 100000.,
#         30000., 135000., 220000., 175000., 185000.,     nan, 145000.,
#        155000.,    350.])

# %%
df["Salary"].min()
# Out:
# np.float64(350.0)

# %%
df["Salary"].max()
# Out:
# np.float64(250000.0)

# %%
df["Salary"].mean()
# Out:
# np.float64(100577.34584450402)

# %%
df.groupby("Job Title")["Salary"].mean().sort_values(ascending=False)
# Out:
# Job Title
# Chief Technology Officer              250000.0
# CEO                                   250000.0
# Chief Data Officer                    220000.0
# Director                              200000.0
# VP of Finance                         200000.0
#                                         ...
# Data Entry Clerk                       35000.0
# Help Desk Analyst                      35000.0
# Junior Customer Support Specialist     35000.0
# Sales Representative                   30000.0
# Junior Business Operations Analyst     17675.0
# Name: Salary, Length: 174, dtype: float64

# %%
df.groupby("Education Level")["Salary"].mean().sort_values(ascending=False)
# Out:
# Education Level
# PhD           157843.137255
# Master's      129795.918367
# Bachelor's     74756.026786
# Name: Salary, dtype: float64

# %%
df.groupby("Gender")["Salary"].mean().sort_values(ascending=False)
# Out:
# Gender
# Male      103867.783505
# Female     97011.173184
# Name: Salary, dtype: float64

# %%
df[["Salary","Years of Experience"]].corr()
# Out:
#                        Salary  Years of Experience
# Salary               1.000000             0.930338
# Years of Experience  0.930338             1.000000

# %% [markdown]
# ### <span style="color:orange">Distribution on various columns</span>

# %%
df["Gender"].value_counts().plot(kind="bar")
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
df["Education Level"].value_counts().plot(kind="bar")
plt.title("Education Level Distribution")
plt.xlabel("Education Level")
plt.ylabel("Number of Employees")
plt.show()

# %%
plt.hist(df["Salary"], bins=15)
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()
